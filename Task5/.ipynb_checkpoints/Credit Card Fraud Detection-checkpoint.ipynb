# %% [markdown]
# ## Importing Necessary Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from matplotlib import gridspec

# %% [markdown]
# ## Data Analysis

# %%
df=pd.read_csv('./creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ## Data CLeaning

# %% [markdown]
# #### Identifying and Handling null values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ##### No NUll Values

# %% [markdown]
# #### Identifying and handling duplicated values

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# ## Data Visualization

# %%
Genunine=len(df[df["Class"]==0])
Genunine_percent=Genunine/df.shape[0]
print(f"Genunine Transaction : {Genunine_percent*100}%")

Fraud=len(df[df["Class"]==1])
Fraud_percent=Fraud/df.shape[0]
print(f"Fraudulant Transaction : {Fraud_percent*100}%")
# Out:
# Genunine Transaction : 99.83328986416473%
# Fraudulant Transaction : 0.1667101358352777%

# %%
plot=[Genunine,Fraud]
label=["Genunine Transaction","Fradulent Transaction"]
plt.pie(plot,labels=label,startangle=90,autopct='%1.1f%%',pctdistance=0.85)
# Out:
# ([<matplotlib.patches.Wedge at 0x17c89aa9a50>,
# ...
#  [Text(-0.0057609965541565, -1.0999849139505065, 'Genunine Transaction'),
#   Text(0.0057609305774565895, 1.099984914296047, 'Fradulent Transaction')],
#  [Text(-0.004451679155484568, -0.8499883425981185, '99.8%'),
#   Text(0.004451628173489182, 0.8499883428651271, '0.2%')])

# %%
plt.bar(label,plot)
plt.xlabel("Class")
plt.title("Visualisation of Classes ")
plt.ylabel("Count")
plt.xticks(range(2), label)
plt.show()

# %% [markdown]
# There is an imbalance in the data, with only 0.17% of the total cases being fraudulent.
#
# Now we look at the distribution of the two named features in the dataset. For Time, it is clear that there was a particular duration in the day when most of the transactions took place:

# %%
f, axes=plt.subplots(1,2,figsize=(18,4),sharex=True)

amount_value=df['Amount'].values
time_value=df['Time'].values

sns.distplot(amount_value, hist=True, color='m', kde_kws={"shade":True}, ax=axes[0]).set_title('Distribution of Amount')
sns.distplot(time_value, hist=True, color='m', kde_kws={"shade":True}, ax=axes[1]).set_title('Distribution of Time')
# Out:
# Text(0.5, 1.0, 'Distribution of Time')

# %% [markdown]
# checking if there is any difference between valid transactions and fraudulent transactions:

# %%
print("Average Amount of Fraudlent Transactions: ", df[df["Class"]==1]["Amount"].mean())
print("Average Amount of Valid Transactions: ", df[df["Class"]==0]["Amount"].mean())
# Out:
# Average Amount of Fraudlent Transactions:  123.87186046511628
# Average Amount of Valid Transactions:  88.41357475472456

# %% [markdown]
# As we notices above, that the average money transaction for the fraudulent transcations are more.

# %% [markdown]
# Now Let's see the distribution of Amount feature

# %%
df['Amount'].describe()
# Out:
# count    283726.000000
# mean         88.472687
# std         250.399437
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.510000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# ## ML Part

# %% [markdown]
# #### Scaling Dataset

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()

# %%
df[["Time","Amount"]]=scaler.fit_transform(df[["Time","Amount"]])

# %%
df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -0.995290 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -0.995290  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -0.995279 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -0.995279 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -0.995267 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %% [markdown]
# #### Result Metrics

# %%
from sklearn.metrics import accuracy_score,f1_score,recall_score,precision_score,confusion_matrix,ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score

# %%
def model_metrics(Y_test,Y_pred,model_name):
    
    accuracy=accuracy_score(Y_test,Y_pred)*100
    precision=precision_score(Y_test,Y_pred)*100
    recall=recall_score(Y_test,Y_pred)*100
    f1=f1_score(Y_test,Y_pred)*100

    print(f"Accuracy score of {model_name} model is :",accuracy)
    print(f"Precision score of {model_name} model is :",precision)
    print(f"Recall score of {model_name} model is :",recall)
    print(f"f1 score of {model_name} model is :",f1)
    
    return accuracy,precision,recall,f1

# %%
def cvs(X_train,Y_train,model,model_name):
    cvs = cross_val_score(model, X_train, Y_train, cv=10, scoring="accuracy", n_jobs=-1, verbose=2)
    print(f"Cross validation score for {model_name} : {cvs}")
    print(f"Average cross validation score for {model_name} : {cvs.mean()}")

# %%
def draw_confusion_matrix(Y_test,Y_pred,model,model_name):
    cm=confusion_matrix(Y_test,Y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f"Confusion Matrix for {model_name}")
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.33, random_state = 45)

# %% [markdown]
# #### ML Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# #### 1. Logistic Regression

# %%
lr = LogisticRegression() 
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
import pickle

# %%
model_pkl_file = "Linear_Regression.pkl"  
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(lr, file)

# %%
model_pkl_file = "Linear_Regression.pkl"
with open(model_pkl_file, 'rb') as file:  
    lr=pickle.load(file)

# %%
Y_pred=lr.predict(X_test)

# %%
lr_accuracy,lr_precision,lr_recall,lr_f1=model_metrics(Y_test,Y_pred,"Linear Regression")
# Out:
# Accuracy score of Linear Regression model is : 99.92096550250989
# Precision score of Linear Regression model is : 78.94736842105263
# Recall score of Linear Regression model is : 58.139534883720934
# f1 score of Linear Regression model is : 66.96428571428572

# %%
cvs(X_train,Y_train,lr,"Linear Regression")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   15.6s remaining:   36.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   15.8s finished
# Cross validation score for Linear Regression : [0.99942136 0.99926355 0.99936875 0.99942136 0.99915834 0.99915834
#  0.99926351 0.99947393 0.99894787 0.99942133]
# Average cross validation score for Linear Regression : 0.999289832228478

# %%
draw_confusion_matrix(Y_test,Y_pred,lr,"Linear Regression")

# %% [markdown]
# #### 2. Random Forest Classifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
model_pkl_file = "Random_Forest.pkl"
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(rf, file)

# %%
with open("Random_Forest.pkl", 'rb') as file:  
    rf=pickle.load(file)

# %%
Y_pred=rf.predict(X_test)

# %%
rf_accuracy,rf_precision,rf_recall,rf_f1=model_metrics(Y_test,Y_pred,"Random Forest")
# Out:
# Accuracy score of Random Forest model is : 99.94766634625654
# Precision score of Random Forest model is : 87.73584905660378
# Recall score of Random Forest model is : 72.09302325581395
# f1 score of Random Forest model is : 79.14893617021278

# %%
cvs(X_train,Y_train,rf,"Random Forest")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.

# %%
draw_confusion_matrix(Y_test,Y_pred,rf,"Random Forest")

# %% [markdown]
# #### 3. Decision Tree Classifier

# %%
dt = DecisionTreeClassifier() 
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
with open("Decision_Tree.pkl", 'wb') as file:  
    pickle.dump(dt, file)

# %%
with open("Decision_Tree.pkl", 'rb') as file:  
    dt=pickle.load(file)

# %%
Y_pred=dt.predict(X_test)

# %%
dt_accuracy,dt_precision,dt_recall,dt_f1=model_metrics(Y_test,Y_pred,"Decision Tree")
# Out:
# Accuracy score of Decision Tree model is : 99.91989746876001
# Precision score of Decision Tree model is : 69.85294117647058
# Recall score of Decision Tree model is : 73.64341085271317
# f1 score of Decision Tree model is : 71.69811320754717

# %%
cvs(X_train,Y_train,dt,"Decision Tree")

# %%
draw_confusion_matrix(Y_test,Y_pred,dt,"Decision Tree")

# %% [markdown]
# #### 4. SVM

# %%
svc=SVC() 
svc.fit(X_train, Y_train)
# Out:
# SVC()

# %%
with open("SVM.pkl", 'wb') as file:  
    pickle.dump(svc, file)

# %%
with open("SVM.pkl", 'rb') as file:  
    svc=pickle.load(file)

# %%
Y_pred=svc.predict(X_test)

# %%
svc_accuracy,svc_precision,svc_recall,svc_f1=model_metrics(Y_test,Y_pred,"SVM")
# Out:
# Accuracy score of SVM model is : 99.94232617750721
# Precision score of SVM model is : 89.47368421052632
# Recall score of SVM model is : 65.89147286821705
# f1 score of SVM model is : 75.89285714285714

# %%
cvs(X_train,Y_train,svc,"SVM")

# %%
draw_confusion_matrix(Y_test,Y_pred,svc,"SVM")

# %% [markdown]
# #### 5. XgBoost

# %%
xg=XGBClassifier(n_estimators=100, max_depth=2, learning_rate=1, objective='binary:logistic')
xg.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
with open("XgBoost.pkl", 'wb') as file:  
    pickle.dump(xg, file)

# %%
with open("XgBoost.pkl", 'rb') as file:  
    xg=pickle.load(file)

# %%
Y_pred=xg.predict(X_test)

# %%
xg_accuracy,xg_precision,xg_recall,xg_f1=model_metrics(Y_test,Y_pred,"XgBoost")
# Out:
# Accuracy score of XgBoost model is : 99.94232617750721
# Precision score of XgBoost model is : 83.1858407079646
# Recall score of XgBoost model is : 72.86821705426357
# f1 score of XgBoost model is : 77.68595041322314

# %%
cvs(X_train,Y_train,svc,"SVM")

# %%
draw_confusion_matrix(Y_test,Y_pred,svc,"SVM")

# %%
org_models = ['Logistic Regression', 'Random Forest', 'Decision Tree', 'SVM','XgBoost']
acc_scores_original = [lr_accuracy,rf_accuracy, dt_accuracy, svc_accuracy,xg_accuracy]
pre_scores_original = [lr_precision,rf_precision,dt_precision,svc_precision,xg_precision]
rec_scores_original = [lr_recall,rf_recall,dt_recall,svc_recall,xg_recall]
f1_scores_original = [lr_f1,rf_f1,dt_f1,svc_f1,xg_f1]

def add_labels(ax, values):
    for i, txt in enumerate(values):
        ax.annotate(f'{txt:.2f}', (i, txt), textcoords="offset points", xytext=(0,5), ha='center')

# Plotting Accuracy
plt.figure(figsize=(10, 6))
plt.plot(org_models, acc_scores_original, marker='o', label='Accuracy', color='skyblue')
add_labels(plt.gca(), acc_scores_original)
plt.xlabel('Models')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting Precision
plt.figure(figsize=(10, 6))
plt.plot(org_models, pre_scores_original, marker='o', label='Precision', color='lightcoral')
add_labels(plt.gca(), pre_scores_original)
plt.xlabel('Models')
plt.ylabel('Precision (%)')
plt.title('Precision Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting Recall
plt.figure(figsize=(10, 6))
plt.plot(org_models, rec_scores_original, marker='o', label='Recall', color='lightgreen')
add_labels(plt.gca(), rec_scores_original)
plt.xlabel('Models')
plt.ylabel('Recall (%)')
plt.title('Recall Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting F1 Score
plt.figure(figsize=(10, 6))
plt.plot(org_models, f1_scores_original, marker='o', label='F1 Score', color='gold')
add_labels(plt.gca(), f1_scores_original)
plt.xlabel('Models')
plt.ylabel('F1 Score (%)')
plt.title('F1 Score Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Undersampling Using NearMiss Method

# %%
from imblearn.under_sampling import NearMiss

X_resampled, Y_resampled = NearMiss().fit_resample(X, Y)

print("Resampled shape of X: ", X_resampled.shape)
print("Resampled shape of Y: ", Y_resampled.shape)

X_train, X_test, Y_train, Y_test = train_test_split(X_resampled, Y_resampled, test_size = 0.33, random_state = 45)
# Out:
# Resampled shape of X:  (946, 30)
# Resampled shape of Y:  (946,)

# %% [markdown]
# #### 1. Logistic Regression

# %%
lr = LogisticRegression() 
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
model_pkl_file = "Linear_Regression_Undersampling.pkl"  
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(lr, file)

# %%
model_pkl_file = "Linear_Regression_Undersampling.pkl"
with open(model_pkl_file, 'rb') as file:  
    lr=pickle.load(file)

# %%
Y_pred=lr.predict(X_test)

# %%
un_lr_accuracy,un_lr_precision,un_lr_recall,un_lr_f1=model_metrics(Y_test,Y_pred,"Linear Regression")
# Out:
# Accuracy score of Linear Regression model is : 92.65175718849841
# Precision score of Linear Regression model is : 97.27891156462584
# Recall score of Linear Regression model is : 88.27160493827161
# f1 score of Linear Regression model is : 92.55663430420714

# %%
cvs(X_train,Y_train,lr,"Linear Regression")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Cross validation score for Linear Regression : [0.96875    0.96875    0.921875   0.93650794 0.92063492 0.95238095
#  0.95238095 0.96825397 0.98412698 0.96825397]
# Average cross validation score for Linear Regression : 0.9541914682539682
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    3.8s remaining:    8.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.9s finished

# %%
draw_confusion_matrix(Y_test,Y_pred,lr,"Linear Regression")

# %% [markdown]
# #### 2. Random Forest Classifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
model_pkl_file = "Random_Forest_Undersampling.pkl"
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(rf, file)

# %%
with open("Random_Forest_Undersampling.pkl", 'rb') as file:  
    rf=pickle.load(file)

# %%
Y_pred=rf.predict(X_test)

# %%
un_rf_accuracy,un_rf_precision,un_rf_recall,un_rf_f1=model_metrics(Y_test,Y_pred,"Random Forest")
# Out:
# Accuracy score of Random Forest model is : 95.52715654952077
# Precision score of Random Forest model is : 98.05194805194806
# Recall score of Random Forest model is : 93.20987654320987
# f1 score of Random Forest model is : 95.56962025316457

# %%
cvs(X_train,Y_train,rf,"Random Forest")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    2.1s remaining:    5.0s
# Cross validation score for Random Forest : [0.96875    0.96875    0.953125   0.96825397 0.93650794 0.98412698
#  0.98412698 0.98412698 1.         0.98412698]
# Average cross validation score for Random Forest : 0.9731894841269841
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   12.5s finished

# %%
draw_confusion_matrix(Y_test,Y_pred,rf,"Random Forest")

# %% [markdown]
# #### 3. Decision Tree Classifier

# %%
dt = DecisionTreeClassifier() 
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
with open("Decision_Tree_Undersampling.pkl", 'wb') as file:  
    pickle.dump(dt, file)

# %%
with open("Decision_Tree_Undersampling.pkl", 'rb') as file:  
    dt=pickle.load(file)

# %%
Y_pred=dt.predict(X_test)

# %%
un_dt_accuracy,un_dt_precision,un_dt_recall,un_dt_f1=model_metrics(Y_test,Y_pred,"Decision Tree")
# Out:
# Accuracy score of Decision Tree model is : 93.29073482428115
# Precision score of Decision Tree model is : 93.7888198757764
# Recall score of Decision Tree model is : 93.20987654320987
# f1 score of Decision Tree model is : 93.49845201238391

# %%
cvs(X_train,Y_train,dt,"Decision Tree")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.2s remaining:    0.5s
# Cross validation score for Decision Tree : [0.984375   0.953125   0.9375     0.93650794 0.93650794 0.96825397
#  0.98412698 0.96825397 0.98412698 0.96825397]
# Average cross validation score for Decision Tree : 0.9621031746031745
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.5s finished

# %%
draw_confusion_matrix(Y_test,Y_pred,dt,"Decision Tree")

# %% [markdown]
# #### 4. SVM

# %%
svc=SVC() 
svc.fit(X_train, Y_train)
# Out:
# SVC()

# %%
with open("SVM_Undersampling.pkl", 'wb') as file:  
    pickle.dump(svc, file)

# %%
with open("SVM_Undersampling.pkl", 'rb') as file:  
    svc=pickle.load(file)

# %%
Y_pred=svc.predict(X_test)

# %%
un_svc_accuracy,un_svc_precision,un_svc_recall,un_svc_f1=model_metrics(Y_test,Y_pred,"SVM")
# Out:
# Accuracy score of SVM model is : 92.01277955271566
# Precision score of SVM model is : 99.28057553956835
# Recall score of SVM model is : 85.18518518518519
# f1 score of SVM model is : 91.69435215946844

# %%
cvs(X_train,Y_train,svc,"SVM")
# Out:
# Cross validation score for SVM : [0.90625    0.9375     0.921875   0.92063492 0.87301587 0.96825397
#  0.93650794 0.95238095 0.98412698 0.9047619 ]
# Average cross validation score for SVM : 0.9305307539682539
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.0s finished

# %%
draw_confusion_matrix(Y_test,Y_pred,svc,"SVM")

# %% [markdown]
# #### 5. XgBoost

# %%
xg=XGBClassifier(n_estimators=100, max_depth=2, learning_rate=1, objective='binary:logistic')
xg.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
with open("XgBoost_Undersampling.pkl", 'wb') as file:  
    pickle.dump(xg, file)

# %%
with open("XgBoost_Undersampling.pkl", 'rb') as file:  
    xg=pickle.load(file)

# %%
Y_pred=xg.predict(X_test)

# %%
un_xg_accuracy,un_xg_precision,un_xg_recall,un_xg_f1=model_metrics(Y_test,Y_pred,"XgBoost")
# Out:
# Accuracy score of XgBoost model is : 92.97124600638978
# Precision score of XgBoost model is : 94.87179487179486
# Recall score of XgBoost model is : 91.35802469135803
# f1 score of XgBoost model is : 93.08176100628931

# %%
cvs(X_train,Y_train,svc,"XgBoost")
# Out:
# Cross validation score for SVM : [0.90625    0.9375     0.921875   0.92063492 0.87301587 0.96825397
#  0.93650794 0.95238095 0.98412698 0.9047619 ]
# Average cross validation score for SVM : 0.9305307539682539
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.0s finished

# %%
draw_confusion_matrix(Y_test,Y_pred,svc,"XgBoost")

# %%
org_models = ['Logistic Regression', 'Random Forest', 'Decision Tree', 'SVM','XgBoost']
acc_scores_undersampled = [un_lr_accuracy,un_rf_accuracy, un_dt_accuracy, un_svc_accuracy,un_xg_accuracy]
pre_scores_undersampled = [un_lr_precision,un_rf_precision,un_dt_precision,un_svc_precision,un_xg_precision]
rec_scores_undersampled = [un_lr_recall,un_rf_recall,un_dt_recall,un_svc_recall,un_xg_recall]
f1_scores_undersampled = [un_lr_f1,un_rf_f1,un_dt_f1,un_svc_f1,un_xg_f1]

def add_labels(ax, values):
    for i, txt in enumerate(values):
        ax.annotate(f'{txt:.2f}', (i, txt), textcoords="offset points", xytext=(0,5), ha='center')

# Plotting Accuracy
plt.figure(figsize=(10, 6))
plt.plot(org_models, acc_scores_undersampled, marker='o', label='Accuracy', color='skyblue')
add_labels(plt.gca(), acc_scores_undersampled)
plt.xlabel('Models')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting Precision
plt.figure(figsize=(10, 6))
plt.plot(org_models, pre_scores_undersampled, marker='o', label='Precision', color='lightcoral')
add_labels(plt.gca(), pre_scores_undersampled)
plt.xlabel('Models')
plt.ylabel('Precision (%)')
plt.title('Precision Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting Recall
plt.figure(figsize=(10, 6))
plt.plot(org_models, rec_scores_undersampled, marker='o', label='Recall', color='lightgreen')
add_labels(plt.gca(), rec_scores_undersampled)
plt.xlabel('Models')
plt.ylabel('Recall (%)')
plt.title('Recall Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting F1 Score
plt.figure(figsize=(10, 6))
plt.plot(org_models, f1_scores_undersampled, marker='o', label='F1 Score', color='gold')
add_labels(plt.gca(), f1_scores_undersampled)
plt.xlabel('Models')
plt.ylabel('F1 Score (%)')
plt.title('F1 Score Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Oversampling using SMOTE

# %%
from imblearn.over_sampling import SMOTE
X_oversampled, Y_oversampled = SMOTE().fit_resample(X, Y)
print("Resampled shape of X: ", X_oversampled.shape)
print("Resampled shape of Y: ", Y_oversampled.shape)

X_train, X_test, Y_train, Y_test = train_test_split(X_oversampled, Y_oversampled, test_size = 0.33, random_state = 45)
# Out:
# Resampled shape of X:  (566506, 30)
# Resampled shape of Y:  (566506,)

# %% [markdown]
# #### 1. Linear Regression

# %%
lr = LogisticRegression() 
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
model_pkl_file = "Linear_Regression_Oversampling.pkl"  
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(lr, file)

# %%
model_pkl_file = "Linear_Regression_Oversampling.pkl"
with open(model_pkl_file, 'rb') as file:  
    lr=pickle.load(file)

# %%
Y_pred=lr.predict(X_test)

# %%
ov_lr_accuracy,ov_lr_precision,ov_lr_recall,ov_lr_f1=model_metrics(Y_test,Y_pred,"Linear Regression")
# Out:
# Accuracy score of Linear Regression model is : 94.7402204902994
# Precision score of Linear Regression model is : 97.43227352901272
# Recall score of Linear Regression model is : 91.93257587880727
# f1 score of Linear Regression model is : 94.60256121726434

# %%
cvs(X_train,Y_train,lr,"Linear Regression")

# %%
draw_confusion_matrix(Y_test,Y_pred,lr,"Linear Regression")

# %% [markdown]
# #### 2. Random Forest

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
model_pkl_file = "Random_Forest_Oversampling.pkl"
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(rf, file)

# %%
with open("Random_Forest_Oversampling.pkl", 'rb') as file:  
    rf=pickle.load(file)

# %%
Y_pred=rf.predict(X_test)

# %%
ov_rf_accuracy,ov_rf_precision,ov_rf_recall,ov_rf_f1=model_metrics(Y_test,Y_pred,"Random Forest")
# Out:
# Accuracy score of Random Forest model is : 99.98662722589825
# Precision score of Random Forest model is : 99.97333617747441
# Recall score of Random Forest model is : 100.0
# f1 score of Random Forest model is : 99.98666631110163

# %%
cvs(X_train,Y_train,rf,"Random Forest")

# %%
draw_confusion_matrix(Y_test,Y_pred,rf,"Random Forest")

# %% [markdown]
# #### 3. Decision Tree

# %%
dt = DecisionTreeClassifier() 
dt.fit(X_train, Y_train)

# %%
with open("Decision_Tree_Oversampling.pkl", 'wb') as file:  
    pickle.dump(dt, file)

# %%
with open("Decision_Tree_Oversampling.pkl", 'rb') as file:  
    dt=pickle.load(file)

# %%
Y_pred=dt.predict(X_test)

# %%
ov_dt_accuracy,ov_dt_precision,ov_dt_recall,ov_dt_f1=model_metrics(Y_test,Y_pred,"Decision Tree")
# Out:
# Accuracy score of Decision Tree model is : 58.540655907824146
# Precision score of Decision Tree model is : 55.0227179874463
# Recall score of Decision Tree model is : 94.8279724755961
# f1 score of Decision Tree model is : 69.63855516078361

# %%
cvs(X_train,Y_train,dt,"Decision Tree")

# %%
draw_confusion_matrix(Y_test,Y_pred,dt,"Decision Tree")

# %% [markdown]
# #### 4. SVM

# %%
svc=SVC() 
svc.fit(X_train, Y_train)
# Out:
# SVC()

# %%
with open("SVM_Oversampling.pkl", 'wb') as file:  
    pickle.dump(svc, file)

# %%
with open("SVM_Oversampling.pkl", 'rb') as file:  
    svc=pickle.load(file)

# %%
Y_pred=svc.predict(X_test)

# %%
ov_svc_accuracy,ov_svc_precision,ov_svc_recall,ov_svc_f1=model_metrics(Y_test,Y_pred,"SVM")
# Out:
# Accuracy score of SVM model is : 97.80686504731287
# Precision score of SVM model is : 98.46340171069563
# Recall score of SVM model is : 97.14194271083373
# f1 score of SVM model is : 97.79820849354498

# %%
cvs(X_train,Y_train,svc,"SVM")

# %%
draw_confusion_matrix(Y_test,Y_pred,svc,"SVM")

# %% [markdown]
# #### 5. XgBoost

# %%
xg=XGBClassifier(n_estimators=100, max_depth=2, learning_rate=1, objective='binary:logistic')
xg.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
with open("XgBoost_Oversampling.pkl", 'wb') as file:  
    pickle.dump(xg, file)

# %%
with open("XgBoost_Oversampling.pkl", 'rb') as file:  
    xg=pickle.load(file)

# %%
Y_pred=xg.predict(X_test)

# %%
ov_xg_accuracy,ov_xg_precision,ov_xg_recall,ov_xg_f1=model_metrics(Y_test,Y_pred,"XgBoost")
# Out:
# Accuracy score of XgBoost model is : 99.68547235312683
# Precision score of XgBoost model is : 99.48994229972266
# Recall score of XgBoost model is : 99.8847815650504
# f1 score of XgBoost model is : 99.68697096495991

# %%
cvs(X_train,Y_train,svc,"XgBoost")

# %%
draw_confusion_matrix(Y_test,Y_pred,svc,"XgBoost")

# %%
org_models = ['Logistic Regression', 'Random Forest', 'Decision Tree', 'SVM','XgBoost']
acc_scores_oversampled = [ov_lr_accuracy,ov_rf_accuracy, ov_dt_accuracy, ov_svc_accuracy,ov_xg_accuracy]
pre_scores_oversampled = [ov_lr_precision,ov_rf_precision,ov_dt_precision,ov_svc_precision,ov_xg_precision]
rec_scores_oversampled = [ov_lr_recall,ov_rf_recall,ov_dt_recall,ov_svc_recall,ov_xg_recall]
f1_scores_oversampled = [ov_lr_f1,ov_rf_f1,ov_dt_f1,ov_svc_f1,ov_xg_f1]

def add_labels(ax, values):
    for i, txt in enumerate(values):
        ax.annotate(f'{txt:.2f}', (i, txt), textcoords="offset points", xytext=(0,5), ha='center')

# Plotting Accuracy
plt.figure(figsize=(10, 6))
plt.plot(org_models, acc_scores_oversampled, marker='o', label='Accuracy', color='skyblue')
add_labels(plt.gca(), acc_scores_oversampled)
plt.xlabel('Models')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting Precision
plt.figure(figsize=(10, 6))
plt.plot(org_models, pre_scores_oversampled, marker='o', label='Precision', color='lightcoral')
add_labels(plt.gca(), pre_scores_oversampled)
plt.xlabel('Models')
plt.ylabel('Precision (%)')
plt.title('Precision Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting Recall
plt.figure(figsize=(10, 6))
plt.plot(org_models, rec_scores_oversampled, marker='o', label='Recall', color='lightgreen')
add_labels(plt.gca(), rec_scores_oversampled)
plt.xlabel('Models')
plt.ylabel('Recall (%)')
plt.title('Recall Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# Plotting F1 Score
plt.figure(figsize=(10, 6))
plt.plot(org_models, f1_scores_oversampled, marker='o', label='F1 Score', color='gold')
add_labels(plt.gca(), f1_scores_oversampled)
plt.xlabel('Models')
plt.ylabel('F1 Score (%)')
plt.title('F1 Score Comparison')
plt.ylim(0, 150)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Comparing model for original , Umsampled , Oversampled data

# %%
# Data for comparison
models = ['Logistic Regression', 'Random Forest Classifier', 'Decision Tree Classifier', 'SVM','XgBoost Classifier']

# Original dataset scores : acc_scores_original,pre_scores_original,rec_scores_original,f1_scores_original

# Undersampled dataset scores : acc_scores_undersampled, pre_scores_undersampled, rec_scores_undersampled, f1_scores_undersampled

# Oversampled dataset scores : acc_scores_oversampled , pre_scores_oversampled , rec_scores_oversampled , f1_scores_oversample

# Plotting Accuracy Comparison
plt.figure(figsize=(15, 6))
bar_width = 0.2
index = np.arange(len(models))

plt.bar(index, acc_scores_original, width=bar_width, label='Original', color='lightblue')
plt.bar(index + bar_width, acc_scores_undersampled, width=bar_width, label='Undersampled', color='lightcoral')
plt.bar(index + 2 * bar_width, acc_scores_oversampled, width=bar_width, label='Oversampled', color='lightgreen')

plt.xlabel('Models')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Comparison')
plt.xticks(index + bar_width, models)
plt.legend()
plt.show()

plt.figure(figsize=(15, 6))

plt.bar(index, pre_scores_original, width=bar_width, label='Original', color='lightblue')
plt.bar(index + bar_width, pre_scores_undersampled, width=bar_width, label='Undersampled', color='lightcoral')
plt.bar(index + 2 * bar_width, pre_scores_oversampled, width=bar_width, label='Oversampled', color='lightgreen')

plt.xlabel('Models')
plt.ylabel('Precision (%)')
plt.title('Precision Comparison')
plt.xticks(index + bar_width, models)
plt.legend()
plt.show()


plt.figure(figsize=(15, 6))

plt.bar(index, rec_scores_original, width=bar_width, label='Original', color='lightblue')
plt.bar(index + bar_width, rec_scores_undersampled, width=bar_width, label='Undersampled', color='lightcoral')
plt.bar(index + 2 * bar_width, rec_scores_oversampled, width=bar_width, label='Oversampled', color='lightgreen')

plt.xlabel('Models')
plt.ylabel('Recall (%)')
plt.title('Recall Comparison')
plt.xticks(index + bar_width, models)
plt.legend()
plt.show()

plt.figure(figsize=(15, 6))

plt.bar(index, f1_scores_original, width=bar_width, label='Original', color='lightblue')
plt.bar(index + bar_width, f1_scores_undersampled, width=bar_width, label='Undersampled', color='lightcoral')
plt.bar(index + 2 * bar_width, f1_scores_oversampled, width=bar_width, label='Oversampled', color='lightgreen')

plt.xlabel('Models')
plt.ylabel('F1 Score (%)')
plt.title('F1 Score Comparison')
plt.xticks(index + bar_width, models)
plt.legend()
plt.show()
